# %% [markdown]
# # 2. For the same dataset (2 classes, male and female)
#
# a) Use LDA to reduce the dimension from d to d’. (Here d=128)
#
# b) Choose the direction W to reduce the dimension d’ (select appropriate d’).
#
# c) Use d’ features to classify the test cases (any classification algorithm will do, Bayes
# classifier, minimum distance classifier, and so on).

# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
df=pd.read_csv('gender_feature_vectors.csv')

# %%
df
# Out:
#      Unnamed: 0 Unnamed: 1         0         1         2         3         4  \
# 0             1       male -0.066420  0.151611  0.027740  0.052771 -0.066105
# 1             2       male -0.030614  0.049667  0.008084 -0.050324  0.007649
# 2             3       male -0.096178  0.061127  0.035326 -0.035388 -0.090728
# 3             4       male -0.103057  0.085044  0.078333 -0.035873 -0.028163
# 4             5       male -0.125815  0.120046  0.023131 -0.042901  0.038215
# ..          ...        ...       ...       ...       ...       ...       ...
# 795         796     female -0.164731  0.064301  0.058630 -0.017420 -0.157600
# 796         797     female -0.095308  0.051095  0.092913 -0.101745 -0.083153
# 797         798     female -0.202852  0.037039  0.079731 -0.047156 -0.140062
# 798         799     female -0.088300  0.063530  0.049627 -0.026011 -0.172773
# 799         800     female -0.156201  0.055165  0.142716 -0.115393 -0.128982
#
# ...

# %%
df['Unnamed: 1'].value_counts()
# Out:
# female    401
# male      399
# Name: Unnamed: 1, dtype: int64

# %%
df.drop(columns=df.columns[0],inplace=True)
df
# Out:
#     Unnamed: 1         0         1         2         3         4         5  \
# 0         male -0.066420  0.151611  0.027740  0.052771 -0.066105 -0.041232
# 1         male -0.030614  0.049667  0.008084 -0.050324  0.007649 -0.063818
# 2         male -0.096178  0.061127  0.035326 -0.035388 -0.090728 -0.018634
# 3         male -0.103057  0.085044  0.078333 -0.035873 -0.028163  0.004924
# 4         male -0.125815  0.120046  0.023131 -0.042901  0.038215 -0.049677
# ..         ...       ...       ...       ...       ...       ...       ...
# 795     female -0.164731  0.064301  0.058630 -0.017420 -0.157600 -0.022536
# 796     female -0.095308  0.051095  0.092913 -0.101745 -0.083153 -0.028159
# 797     female -0.202852  0.037039  0.079731 -0.047156 -0.140062 -0.080246
# 798     female -0.088300  0.063530  0.049627 -0.026011 -0.172773  0.086218
# 799     female -0.156201  0.055165  0.142716 -0.115393 -0.128982 -0.139830
#
# ...

# %%
df.rename(columns={df.columns[0]:"Class"},inplace=True)
df
# Out:
#       Class         0         1         2         3         4         5  \
# 0      male -0.066420  0.151611  0.027740  0.052771 -0.066105 -0.041232
# 1      male -0.030614  0.049667  0.008084 -0.050324  0.007649 -0.063818
# 2      male -0.096178  0.061127  0.035326 -0.035388 -0.090728 -0.018634
# 3      male -0.103057  0.085044  0.078333 -0.035873 -0.028163  0.004924
# 4      male -0.125815  0.120046  0.023131 -0.042901  0.038215 -0.049677
# ..      ...       ...       ...       ...       ...       ...       ...
# 795  female -0.164731  0.064301  0.058630 -0.017420 -0.157600 -0.022536
# 796  female -0.095308  0.051095  0.092913 -0.101745 -0.083153 -0.028159
# 797  female -0.202852  0.037039  0.079731 -0.047156 -0.140062 -0.080246
# 798  female -0.088300  0.063530  0.049627 -0.026011 -0.172773  0.086218
# 799  female -0.156201  0.055165  0.142716 -0.115393 -0.128982 -0.139830
#
#             6         7         8  ...       118       119       120  \
# ...

# %%
df_test=df.iloc[np.r_[390:400, 790:800]]

# %%
df_train=df.iloc[np.r_[0:390,400:790]]

# %% [markdown]
# ## Computing mean and scatter matrix

# %%
df_male=df_train[[i for i in df.columns[1:]]][:390]
df_male
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.066420  0.151611  0.027740  0.052771 -0.066105 -0.041232 -0.002637
# 1   -0.030614  0.049667  0.008084 -0.050324  0.007649 -0.063818 -0.019530
# 2   -0.096178  0.061127  0.035326 -0.035388 -0.090728 -0.018634 -0.024315
# 3   -0.103057  0.085044  0.078333 -0.035873 -0.028163  0.004924  0.007829
# 4   -0.125815  0.120046  0.023131 -0.042901  0.038215 -0.049677 -0.054258
# ..        ...       ...       ...       ...       ...       ...       ...
# 385 -0.064409  0.111391  0.204528 -0.061478 -0.007144 -0.185951  0.037198
# 386  0.002976  0.060769 -0.016651  0.053049 -0.099903 -0.082844  0.017824
# 387 -0.009311  0.077162  0.031294 -0.089573 -0.038689 -0.031663 -0.012356
# 388 -0.036479  0.063089  0.037658 -0.000695 -0.104741 -0.018407  0.030498
# 389 -0.201210  0.054217  0.173419  0.004309 -0.068915 -0.114538  0.124839
#
#             7         8         9  ...       118       119       120  \
# ...

# %%
df_female=df_train[[i for i in df.columns[1:]]][390:]
df_female
# Out:
#             0         1         2         3         4         5         6  \
# 400  0.001747  0.185678  0.073260  0.042142 -0.088674  0.028186 -0.027830
# 401 -0.091598  0.095340  0.072125 -0.092276 -0.079953  0.047782 -0.004701
# 402 -0.018751  0.088572  0.068894 -0.065700 -0.115126  0.024339 -0.028420
# 403 -0.130889  0.093262  0.122244 -0.110014 -0.157625 -0.036781  0.073908
# 404 -0.037433  0.078158  0.118061 -0.117658 -0.194807 -0.045464 -0.014104
# ..        ...       ...       ...       ...       ...       ...       ...
# 785 -0.017931  0.045591  0.059826 -0.059833 -0.126832  0.070365  0.026347
# 786 -0.039572  0.049409  0.100950 -0.092940 -0.152356 -0.057714 -0.000538
# 787 -0.015170 -0.001116  0.132143 -0.078673 -0.134462 -0.155683 -0.030665
# 788 -0.151263  0.096725  0.075206 -0.047269 -0.233372 -0.019918 -0.072370
# 789 -0.179743  0.104404  0.052260 -0.074608 -0.166008  0.023287  0.006970
#
#             7         8         9  ...       118       119       120  \
# ...

# %%
mean_male=np.mean(df_male)
mean_male
# Out:
# 0     -0.091137
# 1      0.092309
# 2      0.043384
# 3     -0.030786
# 4     -0.093000
#          ...
# 123   -0.118805
# 124    0.021776
# 125   -0.025222
# 126    0.020244
# 127    0.040089
# Length: 128, dtype: float64

# %%
mean_female=np.mean(df_female)
mean_female
# Out:
# 0     -0.116036
# 1      0.076929
# 2      0.081975
# 3     -0.077089
# 4     -0.122499
#          ...
# 123   -0.086894
# 124    0.053799
# 125   -0.031701
# 126    0.004233
# 127    0.025536
# Length: 128, dtype: float64

# %% [markdown]
# Sw matrix (within class)

# %%
#Scatter matrix 1

S1=np.cov(df_male.T) * 390 #len of class 1

# %%
S2=np.cov(df_female.T)* 390 #len of class 2

# %%
Sw=S1+S2

# %% [markdown]
# For Sb (between class) we need mean of whole data

# %%
mean_whole=np.mean(df_train)

# %%
def Sb_i(mean_whole,mean_class,number_of_points,dim):
    return (number_of_points * np.subtract(mean_class,mean_whole).values.reshape(dim,1) @ np.subtract(mean_class,mean_whole).values.reshape(1,dim))

# %%
Sb1=Sb_i(mean_whole,mean_male,390,128)

# %%
Sb2=Sb_i(mean_whole,mean_female,390,128)

# %%
Sb=Sb1+Sb2

# %%
def sorted_eig(A):  # For now we sort 'by convention'. 
    lambdas, vs = np.linalg.eig(A)
    # Next line just sorts values & vectors together in order of decreasing eigenvalues
    lambdas, vs = zip(*sorted(zip(list(lambdas), list(vs.T)),key=lambda x: x[0], reverse=True))
    return lambdas, np.array(vs).T  # un-doing the list-casting from the previous line

# %%
eigen,vs=sorted_eig(np.linalg.inv(Sw) @ Sb)

# %%
eigen
# Out:
# ((5.424456206892791+4.722093625234801j),
#  (5.424456206892791-4.722093625234801j),
#  (0.00015524283541300179+0j),
#  (9.503066068309774e-05+3.357358994378081e-05j),
#  (9.503066068309774e-05-3.357358994378081e-05j),
#  (9.369116247526227e-05+8.551252202891466e-06j),
#  (9.369116247526227e-05-8.551252202891466e-06j),
#  (8.041908439527734e-05+0.00013594235229294225j),
#  (8.041908439527734e-05-0.00013594235229294225j),
#  (6.891242031745355e-05+2.9458592079032847e-05j),
#  (6.891242031745355e-05-2.9458592079032847e-05j),
#  (6.252722774211665e-05+9.762447422509235e-05j),
#  (6.252722774211665e-05-9.762447422509235e-05j),
#  (5.997834471936761e-05+3.7839499430252237e-06j),
#  (5.997834471936761e-05-3.7839499430252237e-06j),
#  (5.880133911766523e-05+3.2989196760964725e-05j),
#  (5.880133911766523e-05-3.2989196760964725e-05j),
#  (5.6863060394737945e-05+0.00015299475840679626j),
#  (5.6863060394737945e-05-0.00015299475840679626j),
#  (5.5621940664634864e-05+6.313167491747633e-05j),
# ...

# %%
vs
# Out:
# array([[-0.10973163+1.01343199e-06j, -0.10973163-1.01343199e-06j,
#         -0.06028728+0.00000000e+00j, ..., -0.05085299-2.08034343e-02j,
#          0.09648958+0.00000000e+00j,  0.02877672+0.00000000e+00j],
#        [-0.11470751+4.99188616e-07j, -0.11470751-4.99188616e-07j,
#         -0.10585916+0.00000000e+00j, ..., -0.02331451+5.90722947e-02j,
#         -0.09450776+0.00000000e+00j,  0.09316701+0.00000000e+00j],
#        [ 0.07693813+3.84969840e-07j,  0.07693813-3.84969840e-07j,
#         -0.0140314 +0.00000000e+00j, ...,  0.08292082-6.41182084e-02j,
#         -0.04236853+0.00000000e+00j, -0.06455742+0.00000000e+00j],
#        ...,
#        [-0.1459063 +4.62377116e-07j, -0.1459063 -4.62377116e-07j,
#         -0.03642281+0.00000000e+00j, ..., -0.06789535+2.58404869e-03j,
#          0.02501848+0.00000000e+00j,  0.09822545+0.00000000e+00j],
#        [ 0.14619935+3.08430451e-06j,  0.14619935-3.08430451e-06j,
#          0.05395095+0.00000000e+00j, ...,  0.13368619-1.18788058e-01j,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(eigen)
plt.xlabel("No of dimensions")
plt.ylabel("Eigen values")
# Out:
# C:\Users\RITHIC\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'Eigen values')

# %% [markdown]
# ## Reducing data
